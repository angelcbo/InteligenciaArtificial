# %% [markdown]
# ![](../Assets/itd.png)
#
# # Inteligencia Artificial
# ## Arboles de decisión DataSet COVID19
# ## SIN USAR:
# ## INTUBADO, UCI,NEUMONIA Y TIPO PACIENTE
# ### José Gabriel Rodriguez Rivas
# ### Angel Omar Ceniceros Berumen
#
#
# #### Conclusiones al  final de este Notebook

# %%
#Code cell 1
#import pandas
import pandas as pd

#create a pandas dataframe called "training" from the titanic-train.csv file
training = pd.read_csv("./Data/Covid2/200723COVID19MEXICO.csv",encoding = "ISO-8859-1")

# %%
training
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0               23/07/2020    1.16E+12       2       4           9     2
# 1               23/07/2020      0e50ac       2       4           9     2
# 2               23/07/2020      1dd91c       2       4           8     1
# 3               23/07/2020      1ad302       2       4          30     1
# 4               23/07/2020      1dd6f1       2       3          15     2
# ...                    ...         ...     ...     ...         ...   ...
# 879603          23/07/2020      1af1ae       1      12          19     2
# 879604          23/07/2020      193226       1       3          26     2
# 879605          23/07/2020      0fe94e       2      12          24     1
# 879606          23/07/2020      118851       2      12           9     1
# 879607          23/07/2020      0a6c4c       1       4          11     1
#
#         ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# ...

# %%
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879608 entries, 0 to 879607
# Data columns (total 35 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   FECHA_ACTUALIZACION  879608 non-null  object
#  1   ID_REGISTRO          879608 non-null  object
#  2   ORIGEN               879608 non-null  int64
#  3   SECTOR               879608 non-null  int64
#  4   ENTIDAD_UM           879608 non-null  int64
#  5   SEXO                 879608 non-null  int64
#  6   ENTIDAD_NAC          879608 non-null  int64
#  7   ENTIDAD_RES          879608 non-null  int64
#  8   MUNICIPIO_RES        879608 non-null  int64
#  9   TIPO_PACIENTE        879608 non-null  int64
#  10  FECHA_INGRESO        879608 non-null  object
#  11  FECHA_SINTOMAS       879608 non-null  object
#  12  FECHA_DEF            879608 non-null  object
#  13  INTUBADO             879608 non-null  int64
#  14  NEUMONIA             879608 non-null  int64
# ...

# %%
training['Survived'] = training['FECHA_DEF'].apply(lambda fecha: 1 if fecha=='9999-99-99' else 0)

# %%
sobrevivientes=0
muertos=0
for sobrevive in training['Survived']:
    if sobrevive == 1:
        sobrevivientes=sobrevivientes+1
    else:
        muertos=muertos+1

# %%
print('sobrevivientes {}'.format(sobrevivientes))
print('muertes {}'.format(muertos))
# Out:
# sobrevivientes 825207
# muertes 54401

# %%
training.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          23/07/2020    1.16E+12       2       4           9     2
# 1          23/07/2020      0e50ac       2       4           9     2
# 2          23/07/2020      1dd91c       2       4           8     1
# 3          23/07/2020      1ad302       2       4          30     1
# 4          23/07/2020      1dd6f1       2       3          15     2
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... OBESIDAD  \
# 0           20            9              2              1  ...        2
# 1            9            9              5              2  ...        1
# 2            8            8             37              2  ...        1
# 3           30           30             44              1  ...        2
# 4           15           15            106              2  ...        2
#
#   RENAL_CRONICA TABAQUISMO  OTRO_CASO  RESULTADO  MIGRANTE  PAIS_NACIONALIDAD  \
# ...

# %% [markdown]
# ### Paso 3: Entrenar y calificar el modelo del árbol de decisiones

# %%
#code cell 8
#create the array for the target values
y_target = training["Survived"].values

# %%
#code cell 9
##columns = ["INTUBADO","NEUMONIA", "UCI", "TIPO_PACIENTE"]
columns = ["SEXO","CARDIOVASCULAR", "EDAD","OBESIDAD", "TIPO_PACIENTE","RESULTADO"]
#create the variable to hold the features that the classifier will use
X_input = training[list(columns)].values

# %%
#code cell 10
#import the tree module from the sklearn library
from sklearn import tree

#create clf_train as a decision tree classifier object
clf_train = tree.DecisionTreeClassifier(criterion="entropy", max_depth=5)

#train the model using the fit() method of the decision tree object. 
#Supply the method with the input variable X_input and the target variable y_target
clf_train = clf_train.fit(X_input, y_target)

# %%
#code cell 11
clf_train.score(X_input,y_target)
# Out:
# 0.939583314385499

# %% [markdown]
# ### Paso 4: Visualizar el árbol

# %%
clasificacion = ['SOBREVIVE','NO SOBREVIVE']

# %%
#code cell 12
from sklearn.externals.six import StringIO
with open("./Data/Covid2/covid.dot", 'w') as f:
    f = tree.export_graphviz(clf_train, out_file=f, feature_names=columns,
                          class_names=clasificacion)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
#code cell 13
#run the Graphviz dot command to convert the .dot file to .png
# !dot -Tpng ./Data/Covid2/covid.dot -o ./Data/Covid2/covid.png

# %%
#code cell 14
#import the Image module from the Ipython.display libary
from IPython.display import Image

#display the decison tree graphic
Image("./Data/Covid2/covid.png")

# %%
import graphviz
dot_data = tree.export_graphviz(
    clf_train,
    out_file = None,
    class_names = clasificacion,
    
    feature_names = columns,
    filled= True,
    rounded= True,
    special_characters = True
)
graph = graphviz.Source(dot_data)
graph.render('CovidColor2',format='png')
graph

# %% [markdown]
# ## Parte 2: Aplicar el modelo del árbol de decisiones

# %% [markdown]
# ### Paso 1: Importar y elaborar los datos
# En este paso, importará y preparará los datos para el análisis.

# %%
#code cell 15
#import the file into the 'testing' dataframe.
testing = pd.read_csv("./Data/Covid2/200723COVID19MEXICO.csv",encoding = "ISO-8859-1")

# %%
testing['Survived'] = testing['FECHA_DEF'].apply(lambda fecha: 1 if fecha=='9999-99-99' else 0)

# %%
testing.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          23/07/2020    1.16E+12       2       4           9     2
# 1          23/07/2020      0e50ac       2       4           9     2
# 2          23/07/2020      1dd91c       2       4           8     1
# 3          23/07/2020      1ad302       2       4          30     1
# 4          23/07/2020      1dd6f1       2       3          15     2
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... OBESIDAD  \
# 0           20            9              2              1  ...        2
# 1            9            9              5              2  ...        1
# 2            8            8             37              2  ...        1
# 3           30           30             44              1  ...        2
# 4           15           15            106              2  ...        2
#
#   RENAL_CRONICA TABAQUISMO  OTRO_CASO  RESULTADO  MIGRANTE  PAIS_NACIONALIDAD  \
# ...

# %%
#code cell 19
#create the variable X_input to hold the features that the classifier will use
X_input = testing[list(columns)].values

# %% [markdown]
# ### Hacer predicciones con el metodo predict del clasificador

# %%
#code cell 20
#apply the model to the testing data and store the result in a pandas dataframe.
#Use X_input as the argurment for the predict() method of the clf_train classifier object

target_labels = clf_train.predict(X_input)

#convert the target array into a pandas dataframe using the pd.DataFrame() method and target as argument
target_labels = pd.DataFrame({'Est_Survival':target_labels, 'ID_REGISTRO':testing['ID_REGISTRO']})

#display the first few rows of the data set
target_labels.head()
# Out:
#    Est_Survival ID_REGISTRO
# 0             1    1.16E+12
# 1             1      0e50ac
# 2             1      1dd91c
# 3             1      1ad302
# 4             1      1dd6f1

# %%
sobrevivientes=0
muertos=0
for sobrevive in target_labels['Est_Survival']:
    if sobrevive == 1:
        sobrevivientes=sobrevivientes+1
    else:
        muertos=muertos+1

# %%
print('sobrevivientes {}'.format(sobrevivientes))
print('muertes {}'.format(muertos))
# Out:
# sobrevivientes 868366
# muertes 11242

# %%
#code cell 21
#import the numpy library as np
import numpy as np
# Load data for all passengers in the variable all_data
all_data = pd.read_csv("./Data/Covid2/200723COVID19MEXICO.csv",encoding = "ISO-8859-1")
all_data['Survived'] = all_data['FECHA_DEF'].apply(lambda fecha: 1 if fecha=='9999-99-99' else 0)

# Merging using the field Name as key, selects only the rows of the two datasets that refer to the same passenger
testing_results = pd.merge(target_labels, all_data[['ID_REGISTRO','Survived']], on=['ID_REGISTRO'])

# Compute the accuracy as a ratio of matching observations to total osbervations. Store this in in the variable acc.
acc = np.sum(testing_results['Est_Survival'] == testing_results['Survived']) / float(len(testing_results))
# Print the result
acc
# Out:
# 0.938150953538421

# %% [markdown]
# ### Parte 3: Evaluar el modelo del árbol de decisiones

# %%
#code cell 22
#import the titanic_all.csv file into a dataframe called all_data. Specify the list of columns to import.
all_data = pd.read_csv(
    "./Data/Covid2/200723COVID19MEXICO.csv",
    encoding = "ISO-8859-1",
    usecols=["SEXO","CARDIOVASCULAR", "EDAD","OBESIDAD", "TIPO_PACIENTE","RESULTADO","FECHA_DEF"]
)
#View info for the new dataframe
all_data.head()
# Out:
#    SEXO  TIPO_PACIENTE   FECHA_DEF  EDAD  CARDIOVASCULAR  OBESIDAD  RESULTADO
# 0     2              1  9999-99-99    28               2         2          1
# 1     2              2  9999-99-99    49               2         1          1
# 2     1              2  19/04/2020    67               2         1          1
# 3     1              1  9999-99-99    41               2         2          1
# 4     2              2  9999-99-99    43               2         2          1

# %%
all_data['Survived'] = all_data['FECHA_DEF'].apply(lambda fecha: 1 if fecha=='9999-99-99' else 0)

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879608 entries, 0 to 879607
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SEXO            879608 non-null  int64
#  1   TIPO_PACIENTE   879608 non-null  int64
#  2   FECHA_DEF       879608 non-null  object
#  3   EDAD            879608 non-null  int64
#  4   CARDIOVASCULAR  879608 non-null  int64
#  5   OBESIDAD        879608 non-null  int64
#  6   RESULTADO       879608 non-null  int64
#  7   Survived        879608 non-null  int64
# dtypes: int64(7), object(1)
# memory usage: 53.7+ MB

# %%
all_data.head()
# Out:
#    SEXO  TIPO_PACIENTE   FECHA_DEF  EDAD  CARDIOVASCULAR  OBESIDAD  RESULTADO  \
# 0     2              1  9999-99-99    28               2         2          1
# 1     2              2  9999-99-99    49               2         1          1
# 2     1              2  19/04/2020    67               2         1          1
# 3     1              1  9999-99-99    41               2         2          1
# 4     2              2  9999-99-99    43               2         2          1
#
#    Survived
# 0         1
# 1         1
# 2         0
# 3         1
# 4         1

# %%
#code cell 25
#Import train_test_split() from the sklearn.model_selection libary 
#from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split

#create the input and target variables as uppercase X and lowercase y. Reuse the columns variable.
X = all_data[list(columns)].values
y = all_data["Survived"].values

#generate the four testing and training data arrays with the train_test_split() method
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.40, random_state=0)

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
#code cell 26
#create the training decision tree object
clf_train = tree.DecisionTreeClassifier(criterion="entropy", max_depth=3)

#fit the training model using the input and target variables
clf_train = clf_train.fit(X_train, y_train)

# %%
#code cell 27
#score the model on the two datasets and store the scores in variables. Convert the scores to strings using str()
train_score = str(clf_train.score(X_train,y_train))
test_score = str(clf_train.score(X_test,y_test))

#output the values in a test string
print('Training score = '+ train_score+' Testing score = '+test_score)
# Out:
# Training score = 0.9382432299285287 Testing score = 0.9380179852434601

# %% [markdown]
# ## Conclusiones
#
# Al inicio intente usar los siguientes campos como parametros para la prediccion:
# **["SEXO","CARDIOVASCULAR", "EDAD","OBESIDAD", "TIPO_PACIENTE"]**
#
#
# El problema era que la prediccion con los datos del csv arrojaba **0 muertos** pero despues analice y no era un problema, esto es muy cierto, ya que estos factores hacen a un **paciente** de COVID de alto riego, pero esa era la clave, para que alguien muriera por tener obesidad, ser muy grande de edad y problemas cardiovasculares, debia de **TENER** covid, ya que sin covid es muy poco probable que alguien muera por eso.
# Entonces cambie los parametros de prediccion a los siguientes
# **["SEXO","CARDIOVASCULAR", "EDAD","OBESIDAD", "TIPO_PACIENTE","RESULTADO"]**
#
#
# Donde resultado me indica que alguien fue diagnosticado de COVID19
# Hice las comparaciones y resulto que el  **numero de muertos** en los datos originales era de **54401** y en la **prediccion** el resultado fueron **11242 muertos**. El resultado es parecido al del analisis anterior, pero aqui estamos pero **aqui el tener covid y ser pasiente de alto riesgo, influye en sobrevivir o no**
